# %%
# Importiamo SOLO i moduli per i grafici e l'analisi
from plotter_singleshot import plot_acquisition
from visibility_analyzer import analyze_visibility

# 1. INCOLLA QUI IL PERCORSO DELLA CARTELLA CHE VUOI PLOTTARE
# Sostituisci i numeri con la data e l'ora della tua acquisizione effettiva
base_path = "acquisitions_singleshot/20260825/20260825_1642_singleshot"

# 2. Genera il grafico di base (Segnale + Temperatura)
print("Generazione grafico di base...")
plot_acquisition(base_path)

# 3. Genera l'analisi di visibilità (Inviluppi + Visibilità + Temperatura)
analysis_config = {
    'prominence': 1.0,
    'savgol_window': 51,  
    'savgol_poly': 3
}

print("Generazione analisi di visibilità...")
analyze_visibility(base_path, analysis_config)
# Out:
# Generazione grafico di base...
# Generazione analisi di visibilità...
